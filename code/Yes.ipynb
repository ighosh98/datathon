# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
import googlemaps
import json
import gmaps
import gmaps.datasets
# Out:
# /home/ighosh/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df1 = pd.read_csv('../dataset.csv', sep='|')

# %%
df1.head()
# Out:
#    cust_id_token current_address3  current_city current_state  \
# 0              1              NaN         JAMBI     INDONESIA
# 1              2      INJAMBAKKAM       CHENNAI    TAMIL NADU
# 2              3       ROODEPOORT  JOHANNESBURG       GAUTENG
# 3              4              NaN         DUBAI         DUBAI
# 4              5              NaN         SIRSA       HARYANA
#
#   current_pin_code permanent_address3 permanent_city permanent_state  \
# 0            36126                NaN        CHENNAI      TAMIL NADU
# 1           600115                NaN         LONDON      MIDDLE SEX
# 2             2169  MANDIR RMC GARDEN           PUNE     MAHARASHTRA
# 3            18582                NaN         BARODA         GUJARAT
# 4           125055                NaN          SIRSA         HARYANA
#
#   permanent_pin_code
# 0             600029
# 1             HA047H
# 2             412207
# 3             390007
# 4             125055

# %%
for column in [1,2,3,5,6,7]:
    df1[df1.columns[column]] = df1[df1.columns[column]].str.upper()

# %%
df1.head()
# Out:
#    cust_id_token current_address3  current_city current_state  \
# 0              1              NaN         JAMBI     INDONESIA
# 1              2      INJAMBAKKAM       CHENNAI    TAMIL NADU
# 2              3       ROODEPOORT  JOHANNESBURG       GAUTENG
# 3              4              NaN         DUBAI         DUBAI
# 4              5              NaN         SIRSA       HARYANA
#
#   current_pin_code permanent_address3 permanent_city permanent_state  \
# 0            36126                NaN        CHENNAI      TAMIL NADU
# 1           600115                NaN         LONDON      MIDDLE SEX
# 2             2169  MANDIR RMC GARDEN           PUNE     MAHARASHTRA
# 3            18582                NaN         BARODA         GUJARAT
# 4           125055                NaN          SIRSA         HARYANA
#
#   permanent_pin_code
# 0             600029
# 1             HA047H
# 2             412207
# 3             390007
# 4             125055

# %%
df2 = df1[df1.columns[:5]].dropna().reset_index(drop=True)

# %%
df2.head()
# Out:
#    cust_id_token   current_address3  current_city      current_state  \
# 0              2        INJAMBAKKAM       CHENNAI         TAMIL NADU
# 1              3         ROODEPOORT  JOHANNESBURG            GAUTENG
# 2              6   TARDEO CIRCLE PT        MUMBAI        MAHARASHTRA
# 3              7            PRADESH      ITANAGAR  ARUNACHAL PRADESH
# 4             10  NEAR CENTURY MALL      FUJAIRAH   FUJAIRA EMIRATES
#
#   current_pin_code
# 0           600115
# 1             2169
# 2           400034
# 3           791111
# 4            50037

# %%
df_current_city = df2.groupby('current_city')

# %%
df_current_city.get_group('GURGAON')
# Out:
#          cust_id_token                    current_address3 current_city  \
# 50                 106                             GURGAON      GURGAON
# 163                311             COURSE ROAD DLF PHASE 5      GURGAON
# 189                362                      SEC 25 MG ROAD      GURGAON
# 196                376              BASEMENT) DLF PHASE IV      GURGAON
# 198                379          POST DAMDAMA DAMDAMA (174)      GURGAON
# 208                394                      SCHOOL KE PASS      GURGAON
# 240                458                       TOWER MANESAR      GURGAON
# 256                495           RYAN INTERNATIONAL SCHOOL      GURGAON
# 322                626  SECTOR 54 GOLF COURSE ROAD HARYANA      GURGAON
# 323                627                              DLF IV      GURGAON
# 240           HARYANA           122050
# 256           HARYANA           122002
# 322           HARYANA           121104
# 323           HARYANA           122009
# 326           HARYANA           122001
# 369           HARYANA           122004
# 374           HARYANA           122001
# 464           HARYANA           122018
# 523           HARYANA           122051
# 561           HARYANA           122001
# 616           HARYANA           122002
# 641           HARYANA           122001
# 743           HARYANA           122001
# 778            ODISHA           767048
# 896       WEST BENGAL           711414
# 913       WEST BENGAL           743504
# 915       WEST BENGAL           743318
# 943           HARYANA           122101
# 944           HARYANA           122101
# 1014          HARYANA           221002
# 1119          HARYANA           122001
# 1140          HARYANA           122001
# 1172          HARYANA           122004
# 1242          HARYANA           122001
# ...               ...              ...
# 7160563       HARYANA           122001
# 7160576       HARYANA           122002
# 7160587       HARYANA           122001
# 7160599       HARYANA           122001
# 7160610       HARYANA           122002
# 7160619       HARYANA           122001
# 7160622       HARYANA           122002
# 7160631       HARYANA           122002
# 7160658       HARYANA           122002
# 7160675       HARYANA           122002
# 7160689       HARYANA           122002
# 7160698       HARYANA           122002
# 7160709       HARYANA           122002
# 7160713       HARYANA           122002
# 7160723       HARYANA           122001
# 7160726       HARYANA           122002
# 7160729       HARYANA           122002
# 7160747       HARYANA           122001
# 7160749       HARYANA           122001
# 7160754       HARYANA           122015
# 7160757       HARYANA           122002
# 7160764       HARYANA           122002
# 7160777       HARYANA           122002
# 7160782       HARYANA           122002
# 7160787       HARYANA           122002
# 7160801       HARYANA           122002
# 7160842       HARYANA           122001
# 7160847       HARYANA           122001
# 7160930       HARYANA           122018
# 7160954       HARYANA           122001
#
# [78374 rows x 5 columns]

# %%
googleapikey = 'AIzaSyB_1IOGpf41gJr7XauDvTk0hhodGJq6JV8'

# %%
google_maps = googlemaps.Client(key=googleapikey)
city = 'MUMBAI'
df_example = df_current_city.get_group(city).sample(n=50).reset_index(drop=True)
df_example['whole_address'] = df_example['current_address3'].str.cat(df_example[['current_city','current_state']], sep=", ")

# %%
df_example
# Out:
#     cust_id_token                     current_address3 current_city  \
# 0         6142440      EASTERN EXPRESS HIGHWAY THANE W       MUMBAI
# 1         5171084               CADELL ROAD NO 5 MAHIM       MUMBAI
# 2         5757098               MAIN GATE POWAI MUMBAI       MUMBAI
# 3         6674551  AVENUE ROAD CHEMBUR ABOVE IDFC BANK       MUMBAI
# 4         1638005            SHIVAJI ROAD OPP DNS BANK       MUMBAI
# 5          945255       VINAYAK CROSS ROAD BANDRA WEST       MUMBAI
# 6         8870456                     ROAD MULUND WEST       MUMBAI
# 7         7974436                               (EAST)       MUMBAI
# 8         3859055                                 EAST       MUMBAI
# 9        10377808     HOUSING SOCIETY LTD ANDHERI EAST       MUMBAI
# 10        4638471                      1ST AGYARI LANE       MUMBAI
# 11        1458646           FANASWADI KALBADEVI MUMBAI       MUMBAI
# 12        1889767                         ANDHERI WEST       MUMBAI
# 13        4265183                  NEAR SAIBABA MANDIR       MUMBAI
# 14        3579256                            T F DONAR       MUMBAI
# 15        3979911                 S K AHIRE MARG WORLI       MUMBAI
# 16        4863377                  LANE NR RACE COURSE       MUMBAI
# 17        6163111                     BALMER LAWRIE CO       MUMBAI
# 18        8521316                    ROAD ANDHERI WEST       MUMBAI
# 19        6511958       ROAD HR RAJ CHAMBERS ANDHERI E       MUMBAI
# 20       10240738                               TARDEO       MUMBAI
# 21        5402991                     E GURUJI MARG NR       MUMBAI
# 22        4815976      MIRA RD EAST NR LA GARDENIA SOC       MUMBAI
# 23        4356713                 BEHIND INFINITY MALL       MUMBAI
# 24         983819                        OPP HDFC BANK       MUMBAI
# 25        9993487    ROAD NO. 7, MIDC, ANDHERI (EAST),       MUMBAI
# 26        2446358               BEHIND CENEMAX THEATRE       MUMBAI
# 27        4549358                     MIDC ANDHERI (E)       MUMBAI
# 28        6022511                      VILE PARLE WEST       MUMBAI
# 29       10486049  OFF W.E.HIGHWAY ROAD, GOREGAON (E),       MUMBAI
# 30        5972931                       SANTACRUZ WEST       MUMBAI
# 31        8610911                 DADAR W KABUTARKHANA       MUMBAI
# 32        5489957            ROAD NAYA NAGAR MIRA ROAD       MUMBAI
# 33        3774274                               COLABA       MUMBAI
# 34        5265659                  COLABA CUFFE PARADE       MUMBAI
# 35        7158885                   ABOVE CAFÉ BARISTA       MUMBAI
# 36        6301945                           BHULESHWAR       MUMBAI
# 37        4637840      NEAR HIMACHAL MITRA MANDAL HALL       MUMBAI
# 38        4295546                   SAMACHAR MARG FORT       MUMBAI
# 39        5752067              S V ROAD KANDIVALI WEST       MUMBAI
# 40        6931000        W NR PENINSULA CORPORATE PARK       MUMBAI
# 41        1635694              NGR KHAR EST BANDRA EST       MUMBAI
# 42        9917327                 AKURLI ROAD KANDIVLI       MUMBAI
# 43       10463854                          ANDHERI - W       MUMBAI
# 44        4829148                           GOREGAON W       MUMBAI
# 45        1308908  SHIVSENA BHAWANNRSHIVAJI PARK DADAR       MUMBAI
# 46        5393525          (W) OPP SACRED HEART SCHOOL       MUMBAI
# 47        8702980                       RD ANDHERI WST       MUMBAI
# 48        1299668               NR ICICI BANK MULUND E       MUMBAI
# 49        8830611               RAWALPADA DAHISAR EAST       MUMBAI
#
#    current_state current_pin_code  \
# 0    MAHARASHTRA           400607
# 1    MAHARASHTRA           400016
# 2    MAHARASHTRA           400076
# 3    MAHARASHTRA           400071
# 4    MAHARASHTRA           421501
# 5    MAHARASHTRA           400050
# 6    MAHARASHTRA           400080
# 7    MAHARASHTRA           400097
# 8    MAHARASHTRA           400093
# 9    MAHARASHTRA           400059
# 10   MAHARASHTRA           400002
# 11   MAHARASHTRA           400002
# 12   MAHARASHTRA           400053
# 13   MAHARASHTRA           400055
# 14   MAHARASHTRA           400088
# 15   MAHARASHTRA           400018
# 16   MAHARASHTRA           400034
# 17   MAHARASHTRA           400015
# 18   MAHARASHTRA           400053
# 19   MAHARASHTRA           400069
# 20   MAHARASHTRA           400026
# 21   MAHARASHTRA           400011
# 22   MAHARASHTRA           401107
# 23   MAHARASHTRA           400064
# 24   MAHARASHTRA           400088
# 25   MAHARASHTRA           400093
# 26   MAHARASHTRA           400022
# 27   MAHARASHTRA           400093
# 28   MAHARASHTRA           400056
# 29   MAHARASHTRA           400063
# 30   MAHARASHTRA           400054
# 31   MAHARASHTRA           400028
# 32   MAHARASHTRA           401107
# 33   MAHARASHTRA           400005
# 34   MAHARASHTRA           400005
# 35   MAHARASHTRA           400053
# 36   MAHARASHTRA           400002
# 37   MAHARASHTRA           400089
# 38   MAHARASHTRA           400021
# 39   MAHARASHTRA           400067
# 40   MAHARASHTRA           400013
# 41   MAHARASHTRA           400051
# 42   MAHARASHTRA           400101
# 43   MAHARASHTRA           400058
# 44   MAHARASHTRA           400104
# 45   MAHARASHTRA           400088
# 46   MAHARASHTRA           400052
# 47   MAHARASHTRA           400053
# 48   MAHARASHTRA           400072
# 49   MAHARASHTRA           400068
#
#                                         whole_address
# 0   EASTERN EXPRESS HIGHWAY THANE W, MUMBAI, MAHAR...
# 1         CADELL ROAD NO 5 MAHIM, MUMBAI, MAHARASHTRA
# 2         MAIN GATE POWAI MUMBAI, MUMBAI, MAHARASHTRA
# 3   AVENUE ROAD CHEMBUR ABOVE IDFC BANK, MUMBAI, M...
# 4      SHIVAJI ROAD OPP DNS BANK, MUMBAI, MAHARASHTRA
# 5   VINAYAK CROSS ROAD BANDRA WEST, MUMBAI, MAHARA...
# 6               ROAD MULUND WEST, MUMBAI, MAHARASHTRA
# 7                         (EAST), MUMBAI, MAHARASHTRA
# 8                           EAST, MUMBAI, MAHARASHTRA
# 9   HOUSING SOCIETY LTD ANDHERI EAST, MUMBAI, MAHA...
# 10               1ST AGYARI LANE, MUMBAI, MAHARASHTRA
# 11    FANASWADI KALBADEVI MUMBAI, MUMBAI, MAHARASHTRA
# 12                  ANDHERI WEST, MUMBAI, MAHARASHTRA
# 13           NEAR SAIBABA MANDIR, MUMBAI, MAHARASHTRA
# 14                     T F DONAR, MUMBAI, MAHARASHTRA
# 15          S K AHIRE MARG WORLI, MUMBAI, MAHARASHTRA
# 16           LANE NR RACE COURSE, MUMBAI, MAHARASHTRA
# 17              BALMER LAWRIE CO, MUMBAI, MAHARASHTRA
# 18             ROAD ANDHERI WEST, MUMBAI, MAHARASHTRA
# 19  ROAD HR RAJ CHAMBERS ANDHERI E, MUMBAI, MAHARA...
# 20                        TARDEO, MUMBAI, MAHARASHTRA
# 21              E GURUJI MARG NR, MUMBAI, MAHARASHTRA
# 22  MIRA RD EAST NR LA GARDENIA SOC, MUMBAI, MAHAR...
# 23          BEHIND INFINITY MALL, MUMBAI, MAHARASHTRA
# 24                 OPP HDFC BANK, MUMBAI, MAHARASHTRA
# 25  ROAD NO. 7, MIDC, ANDHERI (EAST),, MUMBAI, MAH...
# 26        BEHIND CENEMAX THEATRE, MUMBAI, MAHARASHTRA
# 27              MIDC ANDHERI (E), MUMBAI, MAHARASHTRA
# 28               VILE PARLE WEST, MUMBAI, MAHARASHTRA
# 29  OFF W.E.HIGHWAY ROAD, GOREGAON (E),, MUMBAI, M...
# 30                SANTACRUZ WEST, MUMBAI, MAHARASHTRA
# 31          DADAR W KABUTARKHANA, MUMBAI, MAHARASHTRA
# 32     ROAD NAYA NAGAR MIRA ROAD, MUMBAI, MAHARASHTRA
# 33                        COLABA, MUMBAI, MAHARASHTRA
# 34           COLABA CUFFE PARADE, MUMBAI, MAHARASHTRA
# 35            ABOVE CAFÉ BARISTA, MUMBAI, MAHARASHTRA
# 36                    BHULESHWAR, MUMBAI, MAHARASHTRA
# 37  NEAR HIMACHAL MITRA MANDAL HALL, MUMBAI, MAHAR...
# 38            SAMACHAR MARG FORT, MUMBAI, MAHARASHTRA
# 39       S V ROAD KANDIVALI WEST, MUMBAI, MAHARASHTRA
# 40  W NR PENINSULA CORPORATE PARK, MUMBAI, MAHARAS...
# 41       NGR KHAR EST BANDRA EST, MUMBAI, MAHARASHTRA
# 42          AKURLI ROAD KANDIVLI, MUMBAI, MAHARASHTRA
# 43                   ANDHERI - W, MUMBAI, MAHARASHTRA
# 44                    GOREGAON W, MUMBAI, MAHARASHTRA
# 45  SHIVSENA BHAWANNRSHIVAJI PARK DADAR, MUMBAI, M...
# 46   (W) OPP SACRED HEART SCHOOL, MUMBAI, MAHARASHTRA
# 47                RD ANDHERI WST, MUMBAI, MAHARASHTRA
# 48        NR ICICI BANK MULUND E, MUMBAI, MAHARASHTRA
# 49        RAWALPADA DAHISAR EAST, MUMBAI, MAHARASHTRA

# %%
#Result Formatting function
def get_google_results(address, api_key, return_full_response=False):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    geocode_url = geocode_url + "&key={}".format(api_key)
        
    results = requests.get(geocode_url)
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
def get_geocode(addresses):
    test_result = get_google_results("Mumbai, India", googleapikey, True)
    stop_time = 30
    if (test_result['status'] != 'OK'):
        raise ConnectionError('Connection error! Check your API key.')
    results= []

    for address in addresses:
        # While the address geocoding is not finished:
        geocoded = False
        while geocoded is not True:
            # Geocode the address with google
            try:
                geocode_output = get_google_results(address, googleapikey, return_full_response=True)
            except Exception as e:
                print("Major error with {}".format(address))
                print("Skipping!")
                geocoded = True

            if geocode_output['status'] == 'OVER_QUERY_LIMIT':
                time.sleep(stop_time * 60) # sleep for stop time 
                geocoded = False
            else:
                # If we're ok with API use, save the results
                # Note that the results might be empty / non-ok - log this
                if geocode_output['status'] != 'OK':
                    print("Error geocoding {}: {}".format(address, geocode_result['status']))
                print("Geocoded: {}: {}".format(address, geocode_output['status']))
                results.append((geocode_output['latitude'],geocode_output['longitude']))           
                geocoded = True
    return results

# %%
geocode_result = get_geocode(df_example['whole_address'].tolist())
geocode_result
# Out:
# Geocoded: EASTERN EXPRESS HIGHWAY THANE W, MUMBAI, MAHARASHTRA: OK
# Geocoded: CADELL ROAD NO 5 MAHIM, MUMBAI, MAHARASHTRA: OK
# Geocoded: MAIN GATE POWAI MUMBAI, MUMBAI, MAHARASHTRA: OK
# Geocoded: AVENUE ROAD CHEMBUR ABOVE IDFC BANK, MUMBAI, MAHARASHTRA: OK
# Geocoded: SHIVAJI ROAD OPP DNS BANK, MUMBAI, MAHARASHTRA: OK
# Geocoded: VINAYAK CROSS ROAD BANDRA WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD MULUND WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: (EAST), MUMBAI, MAHARASHTRA: OK
# Geocoded: EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: HOUSING SOCIETY LTD ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: 1ST AGYARI LANE, MUMBAI, MAHARASHTRA: OK
# Geocoded: FANASWADI KALBADEVI MUMBAI, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: NEAR SAIBABA MANDIR, MUMBAI, MAHARASHTRA: OK
# Geocoded: T F DONAR, MUMBAI, MAHARASHTRA: OK
# Geocoded: S K AHIRE MARG WORLI, MUMBAI, MAHARASHTRA: OK
# Geocoded: LANE NR RACE COURSE, MUMBAI, MAHARASHTRA: OK
# Geocoded: BALMER LAWRIE CO, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD HR RAJ CHAMBERS ANDHERI E, MUMBAI, MAHARASHTRA: OK
# Geocoded: TARDEO, MUMBAI, MAHARASHTRA: OK
# Geocoded: E GURUJI MARG NR, MUMBAI, MAHARASHTRA: OK
# Geocoded: MIRA RD EAST NR LA GARDENIA SOC, MUMBAI, MAHARASHTRA: OK
# Geocoded: BEHIND INFINITY MALL, MUMBAI, MAHARASHTRA: OK
# Geocoded: OPP HDFC BANK, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD NO. 7, MIDC, ANDHERI (EAST),, MUMBAI, MAHARASHTRA: OK
# Geocoded: BEHIND CENEMAX THEATRE, MUMBAI, MAHARASHTRA: OK
# Geocoded: MIDC ANDHERI (E), MUMBAI, MAHARASHTRA: OK
# Geocoded: VILE PARLE WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: OFF W.E.HIGHWAY ROAD, GOREGAON (E),, MUMBAI, MAHARASHTRA: OK
# Geocoded: SANTACRUZ WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: DADAR W KABUTARKHANA, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD NAYA NAGAR MIRA ROAD, MUMBAI, MAHARASHTRA: OK
# Geocoded: COLABA, MUMBAI, MAHARASHTRA: OK
# Geocoded: COLABA CUFFE PARADE, MUMBAI, MAHARASHTRA: OK
# Geocoded: ABOVE CAFÉ BARISTA, MUMBAI, MAHARASHTRA: OK
# Geocoded: BHULESHWAR, MUMBAI, MAHARASHTRA: OK
# Geocoded: NEAR HIMACHAL MITRA MANDAL HALL, MUMBAI, MAHARASHTRA: OK
# Geocoded: SAMACHAR MARG FORT, MUMBAI, MAHARASHTRA: OK
# Geocoded: S V ROAD KANDIVALI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: W NR PENINSULA CORPORATE PARK, MUMBAI, MAHARASHTRA: OK
# Geocoded: NGR KHAR EST BANDRA EST, MUMBAI, MAHARASHTRA: OK
# Geocoded: AKURLI ROAD KANDIVLI, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI - W, MUMBAI, MAHARASHTRA: OK
# Geocoded: GOREGAON W, MUMBAI, MAHARASHTRA: OK
# Geocoded: SHIVSENA BHAWANNRSHIVAJI PARK DADAR, MUMBAI, MAHARASHTRA: OK
# Geocoded: (W) OPP SACRED HEART SCHOOL, MUMBAI, MAHARASHTRA: OK
# Geocoded: RD ANDHERI WST, MUMBAI, MAHARASHTRA: OK
# Geocoded: NR ICICI BANK MULUND E, MUMBAI, MAHARASHTRA: OK
# Geocoded: RAWALPADA DAHISAR EAST, MUMBAI, MAHARASHTRA: OK
# [(19.2045798, 72.9747756),
#  (19.0380317, 72.8391911),
#  (19.1255153, 72.91636799999999),
#  (19.0554516, 72.90035879999999),
#  (19.0185056, 72.83975889999999),
#  (19.0614891, 72.82347399999999),
#  (19.1702179, 72.95454),
#  (19.0759837, 72.8776559),
#  (19.0759837, 72.8776559),
#  (19.1108205, 72.8773475),
#  (18.9513974, 72.83139109999999),
#  (18.9516918, 72.82522279999999),
#  (19.1363246, 72.82766),
#  (19.1788708, 72.8578781),
#  (19.0450816, 72.9188578),
#  (19.0061483, 72.8190748),
#  (18.9842089, 72.8200753),
#  (18.9344207, 72.8415649),
#  (19.127532, 72.8344879),
#  (19.1243209, 72.849668),
#  (18.9681499, 72.8122442),
#  (18.9995013, 72.8398856),
#  (19.2929331, 72.8771337),
#  (19.1412127, 72.8309064),
#  (19.1846541, 72.8361712),
#  (19.11825, 72.871149),
#  (19.1163304, 72.8564143),
#  (19.1174775, 72.8633502),
#  (19.1102949, 72.8409693),
#  (19.1656736, 72.8585435),
#  (19.0815087, 72.8376755),
#  (19.0191552, 72.8394969),
#  (19.28643, 72.86260150000001),
#  (18.9067031, 72.8147123),
#  (18.9126831, 72.8212934),
#  (19.1232809, 72.8641243),
#  (18.9562462, 72.82955419999999),
#  (19.0719916, 72.9030894),
#  (18.930252, 72.83388459999999),
#  (19.2078902, 72.85051849999999),
#  (18.996869, 72.824372),
#  (19.0716903, 72.8341267),
#  (19.2025832, 72.8532795),
#  (19.1363246, 72.82766),
#  (19.1738547, 72.84767180000001),
#  (19.0246308, 72.84049329999999),
#  (19.074292, 72.8384529),
#  (19.1232273, 72.87143449999999),
#  (19.1663916, 72.960199),
#  (19.244455, 72.8680491)]

# %%
df_example['lat_long'] = geocode_result
df_example
# Out:
#     cust_id_token                     current_address3 current_city  \
# 0         6142440      EASTERN EXPRESS HIGHWAY THANE W       MUMBAI
# 1         5171084               CADELL ROAD NO 5 MAHIM       MUMBAI
# 2         5757098               MAIN GATE POWAI MUMBAI       MUMBAI
# 3         6674551  AVENUE ROAD CHEMBUR ABOVE IDFC BANK       MUMBAI
# 4         1638005            SHIVAJI ROAD OPP DNS BANK       MUMBAI
# 5          945255       VINAYAK CROSS ROAD BANDRA WEST       MUMBAI
# 6         8870456                     ROAD MULUND WEST       MUMBAI
# 7         7974436                               (EAST)       MUMBAI
# 8         3859055                                 EAST       MUMBAI
# 9        10377808     HOUSING SOCIETY LTD ANDHERI EAST       MUMBAI
# 10        4638471                      1ST AGYARI LANE       MUMBAI
# 11        1458646           FANASWADI KALBADEVI MUMBAI       MUMBAI
# 12        1889767                         ANDHERI WEST       MUMBAI
# 13        4265183                  NEAR SAIBABA MANDIR       MUMBAI
# 14        3579256                            T F DONAR       MUMBAI
# 15        3979911                 S K AHIRE MARG WORLI       MUMBAI
# 16        4863377                  LANE NR RACE COURSE       MUMBAI
# 17        6163111                     BALMER LAWRIE CO       MUMBAI
# 18        8521316                    ROAD ANDHERI WEST       MUMBAI
# 19        6511958       ROAD HR RAJ CHAMBERS ANDHERI E       MUMBAI
# 20       10240738                               TARDEO       MUMBAI
# 21        5402991                     E GURUJI MARG NR       MUMBAI
# 22        4815976      MIRA RD EAST NR LA GARDENIA SOC       MUMBAI
# 23        4356713                 BEHIND INFINITY MALL       MUMBAI
# 24         983819                        OPP HDFC BANK       MUMBAI
# 25        9993487    ROAD NO. 7, MIDC, ANDHERI (EAST),       MUMBAI
# 26        2446358               BEHIND CENEMAX THEATRE       MUMBAI
# 27        4549358                     MIDC ANDHERI (E)       MUMBAI
# 28        6022511                      VILE PARLE WEST       MUMBAI
# 29       10486049  OFF W.E.HIGHWAY ROAD, GOREGAON (E),       MUMBAI
# 30        5972931                       SANTACRUZ WEST       MUMBAI
# 31        8610911                 DADAR W KABUTARKHANA       MUMBAI
# 32        5489957            ROAD NAYA NAGAR MIRA ROAD       MUMBAI
# 33        3774274                               COLABA       MUMBAI
# 34        5265659                  COLABA CUFFE PARADE       MUMBAI
# 35        7158885                   ABOVE CAFÉ BARISTA       MUMBAI
# 36        6301945                           BHULESHWAR       MUMBAI
# 37        4637840      NEAR HIMACHAL MITRA MANDAL HALL       MUMBAI
# 38        4295546                   SAMACHAR MARG FORT       MUMBAI
# 39        5752067              S V ROAD KANDIVALI WEST       MUMBAI
# 40        6931000        W NR PENINSULA CORPORATE PARK       MUMBAI
# 41        1635694              NGR KHAR EST BANDRA EST       MUMBAI
# 42        9917327                 AKURLI ROAD KANDIVLI       MUMBAI
# 43       10463854                          ANDHERI - W       MUMBAI
# 44        4829148                           GOREGAON W       MUMBAI
# 45        1308908  SHIVSENA BHAWANNRSHIVAJI PARK DADAR       MUMBAI
# 15          S K AHIRE MARG WORLI, MUMBAI, MAHARASHTRA
# 16           LANE NR RACE COURSE, MUMBAI, MAHARASHTRA
# 17              BALMER LAWRIE CO, MUMBAI, MAHARASHTRA
# 18             ROAD ANDHERI WEST, MUMBAI, MAHARASHTRA
# 19  ROAD HR RAJ CHAMBERS ANDHERI E, MUMBAI, MAHARA...
# 20                        TARDEO, MUMBAI, MAHARASHTRA
# 21              E GURUJI MARG NR, MUMBAI, MAHARASHTRA
# 22  MIRA RD EAST NR LA GARDENIA SOC, MUMBAI, MAHAR...
# 23          BEHIND INFINITY MALL, MUMBAI, MAHARASHTRA
# 24                 OPP HDFC BANK, MUMBAI, MAHARASHTRA
# 25  ROAD NO. 7, MIDC, ANDHERI (EAST),, MUMBAI, MAH...
# 26        BEHIND CENEMAX THEATRE, MUMBAI, MAHARASHTRA
# 27              MIDC ANDHERI (E), MUMBAI, MAHARASHTRA
# 28               VILE PARLE WEST, MUMBAI, MAHARASHTRA
# 29  OFF W.E.HIGHWAY ROAD, GOREGAON (E),, MUMBAI, M...
# 30                SANTACRUZ WEST, MUMBAI, MAHARASHTRA
# 31          DADAR W KABUTARKHANA, MUMBAI, MAHARASHTRA
# 32     ROAD NAYA NAGAR MIRA ROAD, MUMBAI, MAHARASHTRA
# 33                        COLABA, MUMBAI, MAHARASHTRA
# 34           COLABA CUFFE PARADE, MUMBAI, MAHARASHTRA
# 35            ABOVE CAFÉ BARISTA, MUMBAI, MAHARASHTRA
# 36                    BHULESHWAR, MUMBAI, MAHARASHTRA
# 37  NEAR HIMACHAL MITRA MANDAL HALL, MUMBAI, MAHAR...
# 38            SAMACHAR MARG FORT, MUMBAI, MAHARASHTRA
# 39       S V ROAD KANDIVALI WEST, MUMBAI, MAHARASHTRA
# 40  W NR PENINSULA CORPORATE PARK, MUMBAI, MAHARAS...
# 41       NGR KHAR EST BANDRA EST, MUMBAI, MAHARASHTRA
# 42          AKURLI ROAD KANDIVLI, MUMBAI, MAHARASHTRA
# 43                   ANDHERI - W, MUMBAI, MAHARASHTRA
# 44                    GOREGAON W, MUMBAI, MAHARASHTRA
# 45  SHIVSENA BHAWANNRSHIVAJI PARK DADAR, MUMBAI, M...
# 46   (W) OPP SACRED HEART SCHOOL, MUMBAI, MAHARASHTRA
# 47                RD ANDHERI WST, MUMBAI, MAHARASHTRA
# 48        NR ICICI BANK MULUND E, MUMBAI, MAHARASHTRA
# 49        RAWALPADA DAHISAR EAST, MUMBAI, MAHARASHTRA
#
#                            lat_long
# 0          (19.2045798, 72.9747756)
# 1          (19.0380317, 72.8391911)
# 2   (19.1255153, 72.91636799999999)
# 3   (19.0554516, 72.90035879999999)
# 4   (19.0185056, 72.83975889999999)
# 5   (19.0614891, 72.82347399999999)
# 6            (19.1702179, 72.95454)
# 7          (19.0759837, 72.8776559)
# 8          (19.0759837, 72.8776559)
# 9          (19.1108205, 72.8773475)
# 10  (18.9513974, 72.83139109999999)
# 11  (18.9516918, 72.82522279999999)
# 12           (19.1363246, 72.82766)
# 13         (19.1788708, 72.8578781)
# 14         (19.0450816, 72.9188578)
# 15         (19.0061483, 72.8190748)
# 16         (18.9842089, 72.8200753)
# 17         (18.9344207, 72.8415649)
# 18          (19.127532, 72.8344879)
# 19          (19.1243209, 72.849668)
# 20         (18.9681499, 72.8122442)
# 21         (18.9995013, 72.8398856)
# 22         (19.2929331, 72.8771337)
# 23         (19.1412127, 72.8309064)
# 24         (19.1846541, 72.8361712)
# 25            (19.11825, 72.871149)
# 26         (19.1163304, 72.8564143)
# 27         (19.1174775, 72.8633502)
# 28         (19.1102949, 72.8409693)
# 29         (19.1656736, 72.8585435)
# 30         (19.0815087, 72.8376755)
# 31         (19.0191552, 72.8394969)
# 32    (19.28643, 72.86260150000001)
# 33         (18.9067031, 72.8147123)
# 34         (18.9126831, 72.8212934)
# 35         (19.1232809, 72.8641243)
# 36  (18.9562462, 72.82955419999999)
# 37         (19.0719916, 72.9030894)
# 38   (18.930252, 72.83388459999999)
# 39  (19.2078902, 72.85051849999999)
# 40           (18.996869, 72.824372)
# 41         (19.0716903, 72.8341267)
# 42         (19.2025832, 72.8532795)
# 43           (19.1363246, 72.82766)
# 44  (19.1738547, 72.84767180000001)
# 45  (19.0246308, 72.84049329999999)
# 46          (19.074292, 72.8384529)
# 47  (19.1232273, 72.87143449999999)
# 48          (19.1663916, 72.960199)
# 49          (19.244455, 72.8680491)

# %%
gmaps.configure(api_key=googleapikey)
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(df_example['lat_long']))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df_pin_code = df2.groupby('current_pin_code')
df_pin_code.get_group('410210')
# Out:
#          cust_id_token                     current_address3  \
# 60                 121      OFF  708 7T FLR SEC 12 KHARGHAR
# 249                479                             KHARGHAR
# 890               1640                       SEC 5 KHARGHAR
# 1049              1892      TOWERS CHS PLOT NO 16 SECTOR 20
# 1128              1998               KHARGHAR PANVEL RAIGAD
# 1851              3274                       NR MTNL OFFICE
# 7978             10630                             KHARGHAR
# 9731             12847                   NAVJEEVAN HOSPITAL
# 12946            16747                 KHARGHAR NAVI MUMBAI
# 15309            19568             BLDG MASCOT IND KHARGHAR
# 16525            21125        8/A SECTOR-08 KHARGHAR PANVEL
# 16603            21241                             KHARGHAR
# 16604            21243                               RAIGAD
# 20033            26552                     KHARGHAR RAIGARH
# 20241            26978  OPPOSITE LITTLE WORLD MALL KHARGHAR
# 20434            27388                              RAIGARH
# 23270            30942                  NAVI MUMBAI RAIGARH
# 27281            35735       NO 8A SECTOR-8 KHARGHAR PANVEL
# 28069            36728                              RAIGARH
# 31316            40686                     COLONY SECTOR 15
# 34390            44473                        PLOT NO 11-13
# 35337            45679                     KHARGHAR RAIGARH
# 37707            49081                       PANVEL RAIGARH
# 37870            49384                                 35 D
# 37871            49385                              RAIGARH
# 38524            50571                             KHARGHAR
# 38949            51360   218 SECT 13 KHARGHAR PANVEL RAIGAD
# 38950            51361  PLAZA PLOT NO-18 27 SECT-7 KHARGHAR
# 39335            52064                   SECTOR-15 KHARGHAR
# 54196            70165          TAL PANVEL KHARGHAR RAIGARH
# 38524                            NAVI MUMBAI   MAHARASHTRA           410210
# 38949                            NAVI MUMBAI   MAHARASHTRA           410210
# 38950    KHARGHAR PANVEL RAIGARH NAVI MUMBAI   MAHARASHTRA           410210
# 39335                                RAIGARH   MAHARASHTRA           410210
# 54196                                RAIGARH   MAHARASHTRA           410210
# ...                                      ...           ...              ...
# 7074718                          NAVI MUMBAI   MAHARASHTRA           410210
# 7077951                          NAVI MUMBAI   MAHARASHTRA           410210
# 7078303                          NAVI MUMBAI   MAHARASHTRA           410210
# 7078474                          NAVI MUMBAI   MAHARASHTRA           410210
# 7079153                          NAVI MUMBAI   MAHARASHTRA           410210
# 7080194                              RAIGARH   MAHARASHTRA           410210
# 7080666                          NAVI MUMBAI   MAHARASHTRA           410210
# 7081873                              RAIGARH   MAHARASHTRA           410210
# 7086299                          NAVI MUMBAI   MAHARASHTRA           410210
# 7086456                          NAVI MUMBAI   MAHARASHTRA           410210
# 7089435                          NAVI MUMBAI   MAHARASHTRA           410210
# 7095949                          NAVI MUMABI   MAHARASHTRA           410210
# 7100457                          NAVI MUMBAI   MAHARASHTRA           410210
# 7102393                          NAVI MUMBAI   MAHARASHTRA           410210
# 7104447                           NEW MUMBAI   MAHARASHTRA           410210
# 7104692                          NAVI MUMBAI   MAHARASHTRA           410210
# 7108644                          NAVI MUMBAI   MAHARASHTRA           410210
# 7110460                          NAVI MUMBAI   MAHARASHTRA           410210
# 7112614                          NAVI MUMBAI   MAHARASHTRA           410210
# 7115197                          NAVI MUMBAI   MAHARASHTRA           410210
# 7124575                          NAVI MUMBAI   MAHARASHTRA           410210
# 7129416                          NAVI MUMBAI   MAHARASHTRA           410210
# 7131326                          NAVI MUMBAI   MAHARASHTRA           410210
# 7132051                          NAVI MUMBAI   MAHARASHTRA           410210
# 7135024                          NAVI MUMBAI   MAHARASHTRA           410210
# 7138386                               RAIGAD   MAHARASHTRA           410210
# 7141726                          NAVI MUMABI   MAHARASHTRA           410210
# 7148032                          NAVI MUMBAI   MAHARASHTRA           410210
# 7149279                           NAVIMUMBAI   MAHARASHTRA           410210
# 7154123                          NAVI MUMBAI   MAHARASHTRA           410210
#
# [3646 rows x 5 columns]

# %%
pin_code = '110047'
df_example2 = df_pin_code.get_group(pin_code).sample(n=50).reset_index(drop=True)
df_example2['whole_address'] = df_example2['current_address3'].str.cat(df_example2[['current_city','current_state']], sep=", ")
df_example2
# Out:
#     cust_id_token                     current_address3  \
# 0         4980213                      MOHALLA JONAPUR
# 1         9412936                MEHRAULI GURGAON ROAD
# 2         7349765                          SOUTH DELHI
# 3         1721997                          SOUTH DELHI
# 4         6259787  NR SANDEEP GENERAL STORE ON MAIN RD
# 5          340819                         GURGAON ROAD
# 6         1009155                    MANDI SOUTH DELHI
# 7         3065030                         ANDREWS GANJ
# 8         5999604           EXTN AYA NAGAR SOUTH DELHI
# 9         5185475                    6 VIJAYA NGR EXTN
# 10       10158563                          MANDI SOUTH
# 11         376390                  NEW DELHI AYA NAGAR
# 12        7237055                    GENRAL STONE NEAR
# 37  NO-1792/2 AYANAGAR EXTN PHASE-IV, NEAR BALKA C...
# 38                  JONAPUR JONAPUR, NEW DELHI, DELHI
# 39           NR ARJANGARH METRO STATION, DELHI, DELHI
# 40                BHAROSE WALI GALI, NEW DELHI, DELHI
# 41                            DELHI, NEW DELHI, DELHI
# 42                 NEAR GOVT SCHOOL, NEW DELHI, DELHI
# 43  PHASE-5 AYA NAGAR EXTN SOUTH DELHI, NEW DELHI,...
# 44                       RESTAURANT, NEW DELHI, DELHI
# 45           PHASE 5 AYA NAGAR EXTN, NEW DELHI, DELHI
# 46  PART OF2 FLR AND GAL NO 2 OPP MCD S, NEW DELHI...
# 47                        AYA NAGAR, NEW DELHI, DELHI
# 48                                DELHI, DELHI, DELHI
# 49                                SOUTH, DELHI, DELHI

# %%
df_example2['lat_long'] = get_geocode(df_example2['whole_address'].tolist())
df_example2
# Out:
# Geocoded: MOHALLA JONAPUR, NEW DELHI, DELHI: OK
# Geocoded: MEHRAULI GURGAON ROAD, NEW DELHI, DELHI: OK
# Geocoded: SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: NR SANDEEP GENERAL STORE ON MAIN RD, NEW DELHI, DELHI: OK
# Geocoded: GURGAON ROAD, NEW DELHI, DELHI: OK
# Geocoded: MANDI SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: ANDREWS GANJ, NEW DELHI, DELHI: OK
# Geocoded: EXTN AYA NAGAR SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: 6 VIJAYA NGR EXTN, DELHI, DELHI: OK
# Geocoded: MANDI SOUTH, DELHI, DELHI: OK
# Geocoded: NEW DELHI AYA NAGAR, NEW DELHI, DELHI: OK
# Geocoded: GENRAL STONE NEAR, NEW DELHI, DELHI: OK
# Geocoded: ROAD AYA NAGAR, NEW DELHI, DELHI: OK
# Geocoded: NEAR BALKA CHOWK, DELHI, DELHI: OK
# Geocoded: NAGAR SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: AGGRAWAL SWEET, NEW DELHI, DELHI: OK
# Geocoded: NEAR BIKANER SWEETS, DELHI, DELHI: OK
# Geocoded: SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: STATION, NEW DELHI, DELHI: OK
# Geocoded: FOREST OFFICE ADARSH ENCLAVE, NEW DELHI, DELHI: OK
# Geocoded: AYA NAGAR AYA NAGAR SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: AYA NAGAR, NEW DELHI, DELHI: OK
# Geocoded: AYA NAGAR EXTENTION, NEW DELHI, DELHI: OK
# Geocoded: AYA NAGAR, NEWDELHI, DELHI: OK
# Geocoded: NR-AGGARWAL SWEETS, DELHI, DELHI: OK
# Geocoded: 530/2 MAIN ROAD AYA NAGAR, NEW DELHI, DELHI: OK
# Geocoded: N/R SHIV MANDIR, NEW DELHI, DELHI: OK
# Geocoded: DELHI, DELHI, DELHI: OK
# Geocoded: NEW DELHI, NEW DELHI, DELHI: OK
# Geocoded: NEAR HANUMAN MANDIR, NEW DELHI, DELHI: OK
# Geocoded: NAGAR EXTN PHASE V AYA NAGAR EXTN, NEW DELHI, DELHI: OK
# Geocoded: PALAM COLONY PALAM, NEW DELHI, DELHI: OK
# Geocoded: CBR CHOWK NEAR BOOSTER PUMP, NEW DELHI, DELHI: OK
# Geocoded: WATER TANK, NEW DELHI, DELHI: OK
# Geocoded: NR ARJUN GARH METRO STATION, NEW DELHI, DELHI: OK
# Geocoded: MARKET AGGARWAL SWEET, DELHI, DELHI: OK
# Geocoded: NO-1792/2 AYANAGAR EXTN PHASE-IV, NEAR BALKA CHOWK NEW DELHI, DELHI: OK
# Geocoded: JONAPUR JONAPUR, NEW DELHI, DELHI: OK
# Geocoded: NR ARJANGARH METRO STATION, DELHI, DELHI: OK
# Geocoded: BHAROSE WALI GALI, NEW DELHI, DELHI: OK
# Geocoded: DELHI, NEW DELHI, DELHI: OK
# Geocoded: NEAR GOVT SCHOOL, NEW DELHI, DELHI: OK
# Geocoded: PHASE-5 AYA NAGAR EXTN SOUTH DELHI, NEW DELHI, DELHI: OK
# Geocoded: RESTAURANT, NEW DELHI, DELHI: OK
# Geocoded: PHASE 5 AYA NAGAR EXTN, NEW DELHI, DELHI: OK
# Geocoded: PART OF2 FLR AND GAL NO 2 OPP MCD S, NEW DELHI, DELHI: OK
# Geocoded: AYA NAGAR, NEW DELHI, DELHI: OK
# Geocoded: DELHI, DELHI, DELHI: OK
# Geocoded: SOUTH, DELHI, DELHI: OK
#     cust_id_token                     current_address3  \
# 0         4980213                      MOHALLA JONAPUR
# 1         9412936                MEHRAULI GURGAON ROAD
# 2         7349765                          SOUTH DELHI
# 3         1721997                          SOUTH DELHI
# 4         6259787  NR SANDEEP GENERAL STORE ON MAIN RD
# 5          340819                         GURGAON ROAD
# 6         1009155                    MANDI SOUTH DELHI
# 7         3065030                         ANDREWS GANJ
# 8         5999604           EXTN AYA NAGAR SOUTH DELHI
# 9         5185475                    6 VIJAYA NGR EXTN
# 10       10158563                          MANDI SOUTH
# 11         376390                  NEW DELHI AYA NAGAR
# 12        7237055                    GENRAL STONE NEAR
# 13         133734                       ROAD AYA NAGAR
# 14        1719728                     NEAR BALKA CHOWK
# 15         796997                    NAGAR SOUTH DELHI
# 16        4392936                       AGGRAWAL SWEET
# 17        4543399                  NEAR BIKANER SWEETS
# 18        6001767                          SOUTH DELHI
# 19        9007757                              STATION
# 20        9988902         FOREST OFFICE ADARSH ENCLAVE
# 21        5994779      AYA NAGAR AYA NAGAR SOUTH DELHI
# 22        4719106                            AYA NAGAR
# 23        1888161                  AYA NAGAR EXTENTION
# 24        3465048                            AYA NAGAR
# 25        1853363                   NR-AGGARWAL SWEETS
# 26        2365418            530/2 MAIN ROAD AYA NAGAR
# 27        2271023                      N/R SHIV MANDIR
# 28        8863489                                DELHI
# 29        4670596                            NEW DELHI
# 30        4182775                  NEAR HANUMAN MANDIR
# 31        1180064    NAGAR EXTN PHASE V AYA NAGAR EXTN
# 32        9910609                   PALAM COLONY PALAM
# 2   (28.4816551, 77.18728569999999)
# 3   (28.4816551, 77.18728569999999)
# 4   (28.5328828, 77.29778089999999)
# 5          (28.4763633, 76.8057603)
# 6          (28.4451711, 77.1443973)
# 7          (28.5626799, 77.2275823)
# 8          (28.4571023, 77.1283821)
# 9   (28.6534037, 77.19144580000001)
# 10         (28.4451711, 77.1443973)
# 11         (28.4720443, 77.1329417)
# 12           (28.569657, 77.241795)
# 13          (28.477713, 77.1294023)
# 14  (28.4753997, 77.13404000000001)
# 15  (28.5335197, 77.21088569999999)
# 16         (28.6390485, 77.1838862)
# 17  (28.6383997, 77.18337939999999)
# 18  (28.4816551, 77.18728569999999)
# 19         (28.6418048, 77.2217462)
# 20         (28.4516284, 77.0306504)
# 21         (28.4720443, 77.1329417)
# 22         (28.4720443, 77.1329417)
# 23         (28.4571023, 77.1283821)
# 24         (28.4720443, 77.1329417)
# 25  (28.5828568, 77.24517709999999)
# 26            (28.4787454, 77.1278)
# 27         (28.5543698, 77.2002864)
# 28  (28.7040592, 77.10249019999999)
# 29         (28.6139391, 77.2090212)
# 30         (28.6449003, 77.1980473)
# 31           (28.47247, 77.1240672)
# 32  (28.5835975, 77.08666459999999)
# 33         (28.4918086, 77.1310921)
# 34         (28.5472421, 77.0352687)
# 35         (28.4807774, 77.1258579)
# 36  (28.6379636, 77.20738349999999)
# 37         (28.4739357, 77.1387266)
# 38         (28.4598526, 77.1571443)
# 39         (28.4807774, 77.1258579)
# 40  (28.4741015, 77.12778879999999)
# 41         (28.6139391, 77.2090212)
# 42         (28.5913442, 77.0621694)
# 43           (28.47247, 77.1240672)
# 44            (28.64109, 77.213876)
# 45           (28.47247, 77.1240672)
# 46          (28.537685, 77.2644361)
# 47         (28.4720443, 77.1329417)
# 48  (28.7040592, 77.10249019999999)
# 49  (28.4816551, 77.18728569999999)

# %%
fig2 = gmaps.figure()
fig2.add_layer(gmaps.heatmap_layer(df_example2['lat_long']))
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
def grouper(g):
    return g.groupby('current_address3')
df_current_city = df2.groupby(['current_city'])
df_current_city.head()
df_address = df_current_city.apply(grouper)
df_address.head()
# Out:
# current_city
# (1) KARNAL                            <pandas.core.groupby.groupby.DataFrameGroupBy ...
# (125) GURGAON                         <pandas.core.groupby.groupby.DataFrameGroupBy ...
# (143) HSG-11 BHIWANI CHARKHI DADRI    <pandas.core.groupby.groupby.DataFrameGroupBy ...
# (154) BHASKOLA FARIDABAD              <pandas.core.groupby.groupby.DataFrameGroupBy ...
# (175) BHARAWALI SHIMLA                <pandas.core.groupby.groupby.DataFrameGroupBy ...
# dtype: object

# %%
def get_street(city_name,street_name,df):
    df_current_city = df2.groupby(['current_city'])
    df_current_city.head()
    dfn = df_current_city.get_group(city_name)
    dfi  = dfn[dfn['current_address3'].str.contains(street_name)]
    return dfi

# %%
df_street_add = get_street('MUMBAI','ANDHERI', df2)
df_street_add.head()
# Out:
#      cust_id_token                     current_address3 current_city  \
# 36              74     MAHAKALI CAVES ROAD ANDHERI EAST       MUMBAI
# 74             149        TOWER LAXMI IND EST ANDHERI W       MUMBAI
# 94             194  SCHOOL ANDHERI WEST ANDHERI RLY STN       MUMBAI
# 104            216                   COMPLEX ANDHERI(W)       MUMBAI
# 135            272                  ANDHERI OPP ABENGOA       MUMBAI
#
#     current_state current_pin_code
# 36    MAHARASHTRA           400093
# 74    MAHARASHTRA           400053
# 94    MAHARASHTRA           400058
# 104   MAHARASHTRA           400053
# 135   MAHARASHTRA           400059

# %%
df_example3 = df_street_add.sample(n=50).reset_index(drop=True)
df_example3['whole_address'] = df_example3['current_address3'].str.cat(df_example3[['current_city','current_state']], sep=", ")
df_example3
# Out:
#     cust_id_token                    current_address3 current_city  \
# 0         8521122                        ANDHERI WEST       MUMBAI
# 1        10003059    NAGAR MAROL MAROSHI RD ANDHERI E       MUMBAI
# 2         4965495             MAJAS DEPOT ANDHERI (E)       MUMBAI
# 3         5139826                  OSHIWARA ANDHERI W       MUMBAI
# 4         1712598                        ANDHERI WEST       MUMBAI
# 5         7294844   MAKWANA ROAD MAROL NAKA ANDHERI E       MUMBAI
# 6         6304732          SAHAR VILLAGE ANDHERI EAST       MUMBAI
# 7         6157526             ANDHERI WEST AZAD NAGAR       MUMBAI
# 8         3117862      A C G ROAD CHAKALA ANDHERI (E)       MUMBAI
# 9        10517977       LOKANDWALA COMPLEX, ANDHERI W       MUMBAI
# 10        9790982     PLOT 384 B ANDHERI E PUMP HOUSE       MUMBAI
# 11       10505682                        ANDHERI WEST       MUMBAI
# 12        2572467  LINK ROAD ANDHERI-W NR CHAI COFFEE       MUMBAI
# 13        4696959                        ANDHERI (E),       MUMBAI
# 14        2971220  ANDHERI EAST NR MAROL FIRE BRIGADE       MUMBAI
# 15        1655206         GUNDAVALI HILL ANDHERI EAST       MUMBAI
# 16         163063               BUNGALOWS ANDHERI (W)       MUMBAI
# 17        6207806                        ANDHERI EAST       MUMBAI
# 18        9936504                           ANDHERI W       MUMBAI
# 19        6221076          NEW LINK ROAD ANDHERI WEST       MUMBAI
# 20        4996526                  MAROL ANDHERI EAST       MUMBAI
# 21        5971802          SHASTRI NAGAR ANDHERI WEST       MUMBAI
# 22        4459596                     FILMS ANDHERI W       MUMBAI
# 23        9137078  COMPLEX KURLA ANDHERI ROAD ANDHERI       MUMBAI
# 24        1815920      ANDHERI WEST MUMBAI AZAD NAGAR       MUMBAI
# 25        2532275                        ANDHERI EAST       MUMBAI
# 26        9237745                   ROAD ANDHERI EAST       MUMBAI
# 27        9898710                   ROAD ANDHERI-EAST       MUMBAI
# 28       10589131            CHANDIVALI , ANDHERI (E)       MUMBAI
# 29        3422232                 LINK ROAD ANDHERI W       MUMBAI
# 30        9810380                        ANDHERI EAST       MUMBAI
# 31        5005996                      AREA ANDHERI E       MUMBAI
# 32        1379375               ROAD ANDHERI E MUMBAI       MUMBAI
# 33       10129275           SHASTRI NAGAR ANDHERI (W)       MUMBAI
# 34        7946360   KURLA ROAD J B NAGAR ANDHERI EAST       MUMBAI
# 35        5740739   ANDHERI (EAST) MUMBAI MUMBAI CITY       MUMBAI
# 48            NAGAR ANDHERI EAST, MUMBAI, MAHARASHTRA
# 49            GULLI ANDHERI EAST, MUMBAI, MAHARASHTRA

# %%
df_example3['lat_long'] = get_geocode(df_example3['whole_address'].tolist())
df_example3
# Out:
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: NAGAR MAROL MAROSHI RD ANDHERI E, MUMBAI, MAHARASHTRA: OK
# Geocoded: MAJAS DEPOT ANDHERI (E), MUMBAI, MAHARASHTRA: OK
# Geocoded: OSHIWARA ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: MAKWANA ROAD MAROL NAKA ANDHERI E, MUMBAI, MAHARASHTRA: OK
# Geocoded: SAHAR VILLAGE ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST AZAD NAGAR, MUMBAI, MAHARASHTRA: OK
# Geocoded: A C G ROAD CHAKALA ANDHERI (E), MUMBAI, MAHARASHTRA: OK
# Geocoded: LOKANDWALA COMPLEX, ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: PLOT 384 B ANDHERI E PUMP HOUSE, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: LINK ROAD ANDHERI-W NR CHAI COFFEE, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI (E),, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST NR MAROL FIRE BRIGADE, MUMBAI, MAHARASHTRA: OK
# Geocoded: GUNDAVALI HILL ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: BUNGALOWS ANDHERI (W), MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: NEW LINK ROAD ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: MAROL ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: SHASTRI NAGAR ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: FILMS ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: COMPLEX KURLA ANDHERI ROAD ANDHERI, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST MUMBAI AZAD NAGAR, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD ANDHERI-EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: CHANDIVALI , ANDHERI (E), MUMBAI, MAHARASHTRA: OK
# Geocoded: LINK ROAD ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: AREA ANDHERI E, MUMBAI, MAHARASHTRA: OK
# Geocoded: ROAD ANDHERI E MUMBAI, MUMBAI, MAHARASHTRA: OK
# Geocoded: SHASTRI NAGAR ANDHERI (W), MUMBAI, MAHARASHTRA: OK
# Geocoded: KURLA ROAD J B NAGAR ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI (EAST) MUMBAI MUMBAI CITY, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: D N NAGAR METRO STATION ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI (W), MUMBAI, MAHARASHTRA: OK
# Geocoded: LINK RD ANDHERI WEST OPP CITY MALL, MUMBAI, MAHARASHTRA: OK
# Geocoded: MIDC ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: LOKHANDWALA RD ANDHERI W, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: ANDHERI WEST, MUMBAI, MAHARASHTRA: OK
# Geocoded: LELEWADI ANDHERI EAST MUMBAI, MUMBAI, MAHARASHTRA: OK
# Geocoded: NAGAR ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
# Geocoded: GULLI ANDHERI EAST, MUMBAI, MAHARASHTRA: OK
#     cust_id_token                    current_address3 current_city  \
# 0         8521122                        ANDHERI WEST       MUMBAI
# 1        10003059    NAGAR MAROL MAROSHI RD ANDHERI E       MUMBAI
# 2         4965495             MAJAS DEPOT ANDHERI (E)       MUMBAI
# 3         5139826                  OSHIWARA ANDHERI W       MUMBAI
# 4         1712598                        ANDHERI WEST       MUMBAI
# 5         7294844   MAKWANA ROAD MAROL NAKA ANDHERI E       MUMBAI
# 6         6304732          SAHAR VILLAGE ANDHERI EAST       MUMBAI
# 7         6157526             ANDHERI WEST AZAD NAGAR       MUMBAI
# 8         3117862      A C G ROAD CHAKALA ANDHERI (E)       MUMBAI
# 9        10517977       LOKANDWALA COMPLEX, ANDHERI W       MUMBAI
# 10        9790982     PLOT 384 B ANDHERI E PUMP HOUSE       MUMBAI
# 11       10505682                        ANDHERI WEST       MUMBAI
# 12        2572467  LINK ROAD ANDHERI-W NR CHAI COFFEE       MUMBAI
# 13        4696959                        ANDHERI (E),       MUMBAI
# 14        2971220  ANDHERI EAST NR MAROL FIRE BRIGADE       MUMBAI
# 15        1655206         GUNDAVALI HILL ANDHERI EAST       MUMBAI
# 16         163063               BUNGALOWS ANDHERI (W)       MUMBAI
# 17        6207806                        ANDHERI EAST       MUMBAI
# 18        9936504                           ANDHERI W       MUMBAI
# 19        6221076          NEW LINK ROAD ANDHERI WEST       MUMBAI
# 20        4996526                  MAROL ANDHERI EAST       MUMBAI
# 21        5971802          SHASTRI NAGAR ANDHERI WEST       MUMBAI
# 22        4459596                     FILMS ANDHERI W       MUMBAI
# 39   MAHARASHTRA           400058
# 40   MAHARASHTRA           400093
# 41   MAHARASHTRA           400053
# 42   MAHARASHTRA           400053
# 43   MAHARASHTRA           400093
# 44   MAHARASHTRA           400053
# 45   MAHARASHTRA           400099
# 46   MAHARASHTRA           400053
# 47   MAHARASHTRA           400059
# 48   MAHARASHTRA           400059
# 49   MAHARASHTRA           400069
#
#                                         whole_address  \
# 0                   ANDHERI WEST, MUMBAI, MAHARASHTRA
# 1   NAGAR MAROL MAROSHI RD ANDHERI E, MUMBAI, MAHA...
# 2        MAJAS DEPOT ANDHERI (E), MUMBAI, MAHARASHTRA
# 3             OSHIWARA ANDHERI W, MUMBAI, MAHARASHTRA
# 4                   ANDHERI WEST, MUMBAI, MAHARASHTRA
# 5   MAKWANA ROAD MAROL NAKA ANDHERI E, MUMBAI, MAH...
# 6     SAHAR VILLAGE ANDHERI EAST, MUMBAI, MAHARASHTRA
# 7        ANDHERI WEST AZAD NAGAR, MUMBAI, MAHARASHTRA
# 8   A C G ROAD CHAKALA ANDHERI (E), MUMBAI, MAHARA...
# 9   LOKANDWALA COMPLEX, ANDHERI W, MUMBAI, MAHARAS...
# 10  PLOT 384 B ANDHERI E PUMP HOUSE, MUMBAI, MAHAR...
# 11                  ANDHERI WEST, MUMBAI, MAHARASHTRA
# 12  LINK ROAD ANDHERI-W NR CHAI COFFEE, MUMBAI, MA...
# 13                  ANDHERI (E),, MUMBAI, MAHARASHTRA
# 14  ANDHERI EAST NR MAROL FIRE BRIGADE, MUMBAI, MA...
# 15   GUNDAVALI HILL ANDHERI EAST, MUMBAI, MAHARASHTRA
# 16         BUNGALOWS ANDHERI (W), MUMBAI, MAHARASHTRA
# 17                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 18                     ANDHERI W, MUMBAI, MAHARASHTRA
# 19    NEW LINK ROAD ANDHERI WEST, MUMBAI, MAHARASHTRA
# 20            MAROL ANDHERI EAST, MUMBAI, MAHARASHTRA
# 21    SHASTRI NAGAR ANDHERI WEST, MUMBAI, MAHARASHTRA
# 22               FILMS ANDHERI W, MUMBAI, MAHARASHTRA
# 23  COMPLEX KURLA ANDHERI ROAD ANDHERI, MUMBAI, MA...
# 24  ANDHERI WEST MUMBAI AZAD NAGAR, MUMBAI, MAHARA...
# 25                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 26             ROAD ANDHERI EAST, MUMBAI, MAHARASHTRA
# 27             ROAD ANDHERI-EAST, MUMBAI, MAHARASHTRA
# 28      CHANDIVALI , ANDHERI (E), MUMBAI, MAHARASHTRA
# 29           LINK ROAD ANDHERI W, MUMBAI, MAHARASHTRA
# 30                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 31                AREA ANDHERI E, MUMBAI, MAHARASHTRA
# 32         ROAD ANDHERI E MUMBAI, MUMBAI, MAHARASHTRA
# 33     SHASTRI NAGAR ANDHERI (W), MUMBAI, MAHARASHTRA
# 34  KURLA ROAD J B NAGAR ANDHERI EAST, MUMBAI, MAH...
# 35  ANDHERI (EAST) MUMBAI MUMBAI CITY, MUMBAI, MAH...
# 36                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 37  D N NAGAR METRO STATION ANDHERI W, MUMBAI, MAH...
# 38                  ANDHERI WEST, MUMBAI, MAHARASHTRA
# 39                     ANDHERI W, MUMBAI, MAHARASHTRA
# 40                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 41                   ANDHERI (W), MUMBAI, MAHARASHTRA
# 42  LINK RD ANDHERI WEST OPP CITY MALL, MUMBAI, MA...
# 43             MIDC ANDHERI EAST, MUMBAI, MAHARASHTRA
# 44      LOKHANDWALA RD ANDHERI W, MUMBAI, MAHARASHTRA
# 45                  ANDHERI EAST, MUMBAI, MAHARASHTRA
# 46                  ANDHERI WEST, MUMBAI, MAHARASHTRA
# 47  LELEWADI ANDHERI EAST MUMBAI, MUMBAI, MAHARASHTRA
# 48            NAGAR ANDHERI EAST, MUMBAI, MAHARASHTRA
# 49            GULLI ANDHERI EAST, MUMBAI, MAHARASHTRA
#
#                            lat_long
# 0            (19.1363246, 72.82766)
# 1          (19.1175698, 72.8801399)
# 2          (19.1376983, 72.8672613)
# 3   (19.1483497, 72.84047029999999)
# 4            (19.1363246, 72.82766)
# 5          (19.1098288, 72.8815012)
# 6   (19.1005838, 72.86784250000001)
# 7           (19.1292452, 72.836039)
# 8          (19.1118535, 72.8612866)
# 9          (19.1435906, 72.8246291)
# 10         (19.1257334, 72.8567751)
# 11           (19.1363246, 72.82766)
# 12         (19.1367606, 72.8288814)
# 13         (19.1154908, 72.8726952)
# 14         (19.1081288, 72.8794774)
# 15         (19.1216317, 72.8545149)
# 16         (19.1255406, 72.8252785)
# 17          (19.113645, 72.8697339)
# 18           (19.1363246, 72.82766)
# 19         (19.1460904, 72.8342026)
# 20         (19.1173012, 72.8840395)
# 21  (19.1393862, 72.82939209999999)
# 22         (19.1364835, 72.8288912)
# 23         (19.1056633, 72.8831373)
# 24          (19.1292452, 72.836039)
# 25          (19.113645, 72.8697339)
# 26         (19.1043743, 72.8592949)
# 27          (19.116893, 72.8867823)
# 28  (19.1074911, 72.90176029999999)
# 29         (19.1460904, 72.8342026)
# 30          (19.113645, 72.8697339)
# 31          (19.113645, 72.8697339)
# 32         (19.1162632, 72.8496498)
# 33  (19.1393862, 72.82939209999999)
# 34         (19.1038108, 72.8648511)
# 35         (19.1154908, 72.8726952)
# 36          (19.113645, 72.8697339)
# 37         (19.1283272, 72.8302614)
# 38           (19.1363246, 72.82766)
# 39           (19.1363246, 72.82766)
# 40          (19.113645, 72.8697339)
# 41           (19.1363246, 72.82766)
# 42         (19.1412127, 72.8309064)
# 43         (19.1174775, 72.8633502)
# 44  (19.1473841, 72.82952829999999)
# 45          (19.113645, 72.8697339)
# 46           (19.1363246, 72.82766)
# 47         (19.1074271, 72.8695649)
# 48         (19.1154908, 72.8726952)
# 49         (19.1162632, 72.8496498)

# %%
fig3 = gmaps.figure()
fig3.add_layer(gmaps.heatmap_layer(df_example3['lat_long']))
fig3
# Out:
# Figure(layout=FigureLayout(height='420px'))
